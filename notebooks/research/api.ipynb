# %%
import requests
from requests.auth import HTTPBasicAuth

# %%
url = "https://api.0x.org/swap/v1/quote?sellToken=0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee&buyToken=0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48&sellAmount=1000000000000000000"

api_key = "6cbf2275-5cee-4659-8d67-5491399a9c5e"

headers = {
        'Content-type': 'application/json',
        '0x-api-key': api_key
    }

# %%
headers = { 'Accept': 'application/json', '0x-api-key': api_key}
search_response = requests.get(url, headers=headers)

# %%
print(search_response.json())
# Out:
# {'chainId': 1, 'price': '2992.475579', 'grossPrice': '2996.926014', 'estimatedPriceImpact': '0.0009', 'value': '1000000000000000000', 'gasPrice': '30000000000', 'gas': '160506', 'estimatedGas': '160506', 'protocolFee': '0', 'minimumProtocolFee': '0', 'buyTokenAddress': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48', 'buyAmount': '2992475579', 'grossBuyAmount': '2996926014', 'sellTokenAddress': '0xeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeee', 'sellAmount': '1000000000000000000', 'grossSellAmount': '1000000000000000000', 'sources': [{'name': '0x', 'proportion': '0'}, {'name': 'Uniswap', 'proportion': '0'}, {'name': 'Uniswap_V2', 'proportion': '0'}, {'name': 'Curve', 'proportion': '0'}, {'name': 'Balancer', 'proportion': '0'}, {'name': 'Balancer_V2', 'proportion': '0'}, {'name': 'BancorV3', 'proportion': '0'}, {'name': 'SushiSwap', 'proportion': '0'}, {'name': 'DODO', 'proportion': '0'}, {'name': 'DODO_V2', 'proportion': '0'}, {'name': 'CryptoCom', 'proportion': '0'}, {'name': 'Lido', 'proportion': '0'}, {'name': 'MakerPsm', 'proportion': '0'}, {'name': 'KyberDMM', 'proportion': '0'}, {'name': 'Uniswap_V3', 'proportion': '1'}, {'name': 'Curve_V2', 'proportion': '0'}, {'name': 'ShibaSwap', 'proportion': '0'}, {'name': 'Synapse', 'proportion': '0'}, {'name': 'Synthetix', 'proportion': '0'}, {'name': 'Aave_V2', 'proportion': '0'}, {'name': 'Compound', 'proportion': '0'}, {'name': 'KyberElastic', 'proportion': '0'}, {'name': 'Maverick_V1', 'proportion': '0'}, {'name': 'PancakeSwap_V3', 'proportion': '0'}], 'allowanceTarget': '0x0000000000000000000000000000000000000000', 'sellTokenToEthRate': '1', 'buyTokenToEthRate': '2996.95063', 'expectedSlippage': '-0.00005112541728427235950164696548129264077129', 'to': '0xdef1c0ded9bec7f1a1670819833240f027b25eff', 'data': '...', 'decodedUniqueId': '0x04897d552aa162917d2694c4409df574', 'guaranteedPrice': '2962.506318', 'orders': [{'type': 0, 'source': 'Uniswap_V3', 'makerToken': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48', 'takerToken': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2', 'makerAmount': '2996926014', 'takerAmount': '1000000000000000000', 'fillData': {'router': '0xe592427a0aece92de3edee1f18e0157c05861564', 'path': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc20001f4a0b86991c6218b36c1d19d4a2e9eb0ce3606eb48', 'gasUsed': 9753, 'routerVersion': 1}, 'fill': {'input': '1000000000000000000', 'output': '2996926014', 'adjustedOutput': '2986181586', 'gas': 119504}}], 'fees': {'zeroExFee': {'feeType': 'volume', 'feeToken': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48', 'feeAmount': '4450435', 'billingType': 'on-chain'}}, 'auxiliaryChainData': {}}
